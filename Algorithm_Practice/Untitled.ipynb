# %%
import numpy as np
300_400= np.random.randint(5000, 10000,size=1000)
# Out:
#   File "<ipython-input-53-feb3fba3e2a0>", line 2
#     300_400= np.random.randint(5000, 10000,size=1000)
#                                                      ^
# SyntaxError: can't assign to literal

# %%
import pandas as pd
market_capital = pd.DataFrame(dataset, columns=['market_capital'])

# %%
market_capital.reset_index(inplace=True)
print(market_capital.head())
# Out:
#    index  market_capital
# 0      0            7957
# 1      1            6712
# 2      2            7483
# 3      3            7441
# 4      4            6422

# %%
market_capital.plot(kind='scatter', x='index', y='market_capital', alpha=0.5)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(market_capital[['market_capital']], figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000116F1F36BE0>]],
#       dtype=object)
